# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a = plt.plot(2,3,'x')
plt.plot(3,3,'o')

plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45, fontsize = 17)

plt.xlabel('x_label', fontsize = 17)
plt.ylabel('y_label', fontsize = 17)

plt.title('A title', fontsize = 17)
plt.show()

# %%
##1. Line graph of weight and height

# %%
data = { 'Names': ['Name1', 'Name2', 'Name3', 'Name4', 'Name5', 'Name6'],
        'Age': [25, 30, 30, 25, 25, 35],
        'Weight': [60, 62, 65, 63, 68, 70]
       }

df = pd.DataFrame(data)
df
# Out:
#    Names  Age  Weight
# 0  Name1   25      60
# 1  Name2   30      62
# 2  Name3   30      65
# 3  Name4   25      63
# 4  Name5   25      68
# 5  Name6   35      70

# %%
df.plot(kind='line')
plt.yticks(fontsize = 17)
plt.title('Compraison of Height and Weight of madeup data', fontsize = 17)
plt.show()

# %%
df['Age'].plot(kind = 'hist')
plt.show()
