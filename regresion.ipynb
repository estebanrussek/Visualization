# %% [markdown]
# # Regresion

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %ls 'datasets/'
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           cwurData.csv   pokemon.csv
# antropometria00.csv        data.csv       sample_pivot.csv
# antropometria-dataset.csv  headbrain.csv  tips.csv
# Canada.xlsx                mic.xlsx       weight-height.csv
# Cartwheeldata.csv          movies.csv

# %% [markdown]
# ## Existe una correlación entre Head Size y Brain Weight?

# %%
df = pd.read_csv('datasets/headbrain.csv')
df.head


X = df['Head Size(cm^3)']
Y = df['Brain Weight(grams)']

np.corrcoef(X,Y)
# Out:
# array([[1.        , 0.79956971],
#        [0.79956971, 1.        ]])

# %%
colors = {1: 'red', 2: 'green'}
plt.figure(figsize = (13,8))
plt.scatter(X, Y,
           c = df['Gender'].map(colors),
           marker = 'x',
           s = 175)
plt.xlabel('Head Size(cm^3)', fontweight = 'regular', color = 'black', fontsize = 18, horizontalalignment = 'center')
plt.ylabel('Brain Weight(grams)', fontweight = 'regular', color = 'black', fontsize = 18, horizontalalignment = 'center')
# Out:
# Text(0, 0.5, 'Brain Weight(grams)')

# %% [markdown]
# ## CONCLUSION
# Por lo tanto, la coeficiente de correlacion es 0.79956971, podemos decir, existe una relacion muy fuerte entre Head Size y Brain Weight
